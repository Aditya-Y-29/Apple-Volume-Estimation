# %%
"""
    Exploring different combinations of features and applying various kernal Support Vector Machine Regression (SVR) on each average fitted ellipse 
    parameter subset.
    Here data is standardised before fitting SVMR. 
    Z - Normalisation is used. 
"""
# Out:
# '\n    Exploring different combinations of features and applying various kernal Support Vector Machine Regression (SVR) on each average fitted ellipse \n    parameter subset.\n'

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import ExpSineSquared, RationalQuadratic, Matern, RBF

# %%
df = pd.read_csv('../Data/avg_fitted_ellipse_parameter_and_true_volume.csv')

# %%
columns = ['apple_label', 'semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity', 'volume']

column_dict = {
    0: 'semi_major_axis',
    1: 'semi_minor_axis',
    2: 'area',
    3: 'perimeter',
    4: 'eccentricity'
}

seeds = [0, 10, 20, 30, 40]

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ------------------------------------------- Linear Kernal ---------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)
        scaler = StandardScaler()

        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        svr_model = SVR(kernel='linear')
        svr_model.fit(X_train, y_train)
        y_pred = svr_model.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.947
# Mean Squared Error (MSE): 287.21
# Mean Percentage Error (MPE): 8.737
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.925
# Mean Squared Error (MSE): 286.442
# Mean Percentage Error (MPE): 8.7
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.973
# Mean Squared Error (MSE): 288.068
# Mean Percentage Error (MPE): 8.744
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.88
# Mean Squared Error (MSE): 284.95
# Mean Percentage Error (MPE): 8.684
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.991
# Mean Squared Error (MSE): 288.711
# Mean Percentage Error (MPE): 8.794
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.881
# Mean Squared Error (MSE): 284.952
# Mean Percentage Error (MPE): 8.691
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.289
# Mean Squared Error (MSE): 298.914
# Mean Percentage Error (MPE): 9.137
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.186
# Mean Squared Error (MSE): 295.357
# Mean Percentage Error (MPE): 9.042
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.889
# Mean Squared Error (MSE): 285.251
# Mean Percentage Error (MPE): 8.681
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.922
# Mean Squared Error (MSE): 286.34
# Mean Percentage Error (MPE): 8.701
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.038
# Mean Squared Error (MSE): 290.28
# Mean Percentage Error (MPE): 8.814
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.583
# Mean Squared Error (MSE): 275.007
# Mean Percentage Error (MPE): 8.399
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.946
# Mean Squared Error (MSE): 287.162
# Mean Percentage Error (MPE): 8.767
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.835
# Mean Squared Error (MSE): 283.409
# Mean Percentage Error (MPE): 8.696
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.279
# Mean Squared Error (MSE): 298.555
# Mean Percentage Error (MPE): 9.145
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 30.824
# Mean Squared Error (MSE): 950.095
# Mean Percentage Error (MPE): 16.12
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 17.462
# Mean Squared Error (MSE): 304.933
# Mean Percentage Error (MPE): 9.205
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 17.048
# Mean Squared Error (MSE): 290.638
# Mean Percentage Error (MPE): 8.82
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 18.069
# Mean Squared Error (MSE): 326.485
# Mean Percentage Error (MPE): 9.835
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 17.491
# Mean Squared Error (MSE): 305.929
# Mean Percentage Error (MPE): 9.319
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 17.477
# Mean Squared Error (MSE): 305.455
# Mean Percentage Error (MPE): 9.261
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 16.879
# Mean Squared Error (MSE): 284.907
# Mean Percentage Error (MPE): 8.704
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 18.796
# Mean Squared Error (MSE): 353.284
# Mean Percentage Error (MPE): 10.476
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 17.904
# Mean Squared Error (MSE): 320.562
# Mean Percentage Error (MPE): 9.762
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 17.366
# Mean Squared Error (MSE): 301.576
# Mean Percentage Error (MPE): 9.112
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 16.941
# Mean Squared Error (MSE): 287.004
# Mean Percentage Error (MPE): 8.719
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 18.289
# Mean Squared Error (MSE): 334.505
# Mean Percentage Error (MPE): 10.078
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 17.206
# Mean Squared Error (MSE): 296.039
# Mean Percentage Error (MPE): 9.11
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 17.307
# Mean Squared Error (MSE): 299.54
# Mean Percentage Error (MPE): 9.138
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 16.567
# Mean Squared Error (MSE): 274.47
# Mean Percentage Error (MPE): 8.39
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 21.257
# Mean Squared Error (MSE): 451.855
# Mean Percentage Error (MPE): 12.246

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ------------------------------------------- Guassian Kernal -------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        svr_model = SVR(kernel='rbf')
        svr_model.fit(X_train, y_train)
        y_pred = svr_model.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.167
# Mean Squared Error (MSE): 633.39
# Mean Percentage Error (MPE): 13.457
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.196
# Mean Squared Error (MSE): 634.819
# Mean Percentage Error (MPE): 13.461
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.294
# Mean Squared Error (MSE): 639.81
# Mean Percentage Error (MPE): 13.599
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.347
# Mean Squared Error (MSE): 642.458
# Mean Percentage Error (MPE): 13.633
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.167
# Mean Squared Error (MSE): 633.39
# Mean Percentage Error (MPE): 13.519
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.218
# Mean Squared Error (MSE): 635.958
# Mean Percentage Error (MPE): 13.564
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.276
# Mean Squared Error (MSE): 638.852
# Mean Percentage Error (MPE): 13.674
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.561
# Mean Squared Error (MSE): 653.351
# Mean Percentage Error (MPE): 13.905
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.249
# Mean Squared Error (MSE): 637.49
# Mean Percentage Error (MPE): 13.536
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.303
# Mean Squared Error (MSE): 640.231
# Mean Percentage Error (MPE): 13.578
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.398
# Mean Squared Error (MSE): 645.072
# Mean Percentage Error (MPE): 13.706
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.548
# Mean Squared Error (MSE): 652.723
# Mean Percentage Error (MPE): 13.882
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.285
# Mean Squared Error (MSE): 639.308
# Mean Percentage Error (MPE): 13.644
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.524
# Mean Squared Error (MSE): 651.46
# Mean Percentage Error (MPE): 13.848
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.712
# Mean Squared Error (MSE): 661.108
# Mean Percentage Error (MPE): 14.002
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 32.263
# Mean Squared Error (MSE): 1040.882
# Mean Percentage Error (MPE): 17.002
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 24.339
# Mean Squared Error (MSE): 592.364
# Mean Percentage Error (MPE): 12.748
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 23.893
# Mean Squared Error (MSE): 570.884
# Mean Percentage Error (MPE): 12.416
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 24.615
# Mean Squared Error (MSE): 605.922
# Mean Percentage Error (MPE): 13.063
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 24.245
# Mean Squared Error (MSE): 587.82
# Mean Percentage Error (MPE): 12.675
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 24.348
# Mean Squared Error (MSE): 592.825
# Mean Percentage Error (MPE): 12.785
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 23.755
# Mean Squared Error (MSE): 564.317
# Mean Percentage Error (MPE): 12.317
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 24.871
# Mean Squared Error (MSE): 618.564
# Mean Percentage Error (MPE): 13.25
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 24.196
# Mean Squared Error (MSE): 585.441
# Mean Percentage Error (MPE): 12.715
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 24.404
# Mean Squared Error (MSE): 595.561
# Mean Percentage Error (MPE): 12.777
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 23.798
# Mean Squared Error (MSE): 566.356
# Mean Percentage Error (MPE): 12.246
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 24.803
# Mean Squared Error (MSE): 615.186
# Mean Percentage Error (MPE): 13.189
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 24.205
# Mean Squared Error (MSE): 585.889
# Mean Percentage Error (MPE): 12.602
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 24.44
# Mean Squared Error (MSE): 597.293
# Mean Percentage Error (MPE): 12.838
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 23.544
# Mean Squared Error (MSE): 554.339
# Mean Percentage Error (MPE): 11.922
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 26.244
# Mean Squared Error (MSE): 688.732
# Mean Percentage Error (MPE): 14.151

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ------------------------------------------- Polynomial Kernal -----------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        svr_model = SVR(kernel='poly', degree=3)
        svr_model.fit(X_train, y_train)
        y_pred = svr_model.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.294
# Mean Squared Error (MSE): 453.44
# Mean Percentage Error (MPE): 11.239
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.12
# Mean Squared Error (MSE): 446.039
# Mean Percentage Error (MPE): 11.023
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.241
# Mean Squared Error (MSE): 451.19
# Mean Percentage Error (MPE): 11.095
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.026
# Mean Squared Error (MSE): 442.097
# Mean Percentage Error (MPE): 10.859
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.279
# Mean Squared Error (MSE): 452.811
# Mean Percentage Error (MPE): 11.198
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.304
# Mean Squared Error (MSE): 453.849
# Mean Percentage Error (MPE): 11.118
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.624
# Mean Squared Error (MSE): 467.591
# Mean Percentage Error (MPE): 11.185
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.293
# Mean Squared Error (MSE): 453.372
# Mean Percentage Error (MPE): 10.943
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.102
# Mean Squared Error (MSE): 445.274
# Mean Percentage Error (MPE): 10.97
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.002
# Mean Squared Error (MSE): 441.085
# Mean Percentage Error (MPE): 10.954
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.086
# Mean Squared Error (MSE): 444.6
# Mean Percentage Error (MPE): 10.787
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 20.786
# Mean Squared Error (MSE): 432.038
# Mean Percentage Error (MPE): 11.074
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.444
# Mean Squared Error (MSE): 459.845
# Mean Percentage Error (MPE): 11.165
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.181
# Mean Squared Error (MSE): 448.639
# Mean Percentage Error (MPE): 10.996
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.599
# Mean Squared Error (MSE): 466.525
# Mean Percentage Error (MPE): 10.997
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 29.982
# Mean Squared Error (MSE): 898.92
# Mean Percentage Error (MPE): 14.773
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 24.724
# Mean Squared Error (MSE): 611.264
# Mean Percentage Error (MPE): 14.192
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 23.982
# Mean Squared Error (MSE): 575.156
# Mean Percentage Error (MPE): 13.799
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 25.711
# Mean Squared Error (MSE): 661.074
# Mean Percentage Error (MPE): 14.655
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 24.892
# Mean Squared Error (MSE): 619.61
# Mean Percentage Error (MPE): 14.312
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 24.51
# Mean Squared Error (MSE): 600.759
# Mean Percentage Error (MPE): 14.107
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 23.019
# Mean Squared Error (MSE): 529.889
# Mean Percentage Error (MPE): 13.255
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 25.725
# Mean Squared Error (MSE): 661.776
# Mean Percentage Error (MPE): 14.676
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 24.7
# Mean Squared Error (MSE): 610.077
# Mean Percentage Error (MPE): 14.211
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 24.555
# Mean Squared Error (MSE): 602.968
# Mean Percentage Error (MPE): 14.098
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 23.374
# Mean Squared Error (MSE): 546.332
# Mean Percentage Error (MPE): 13.425
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 26.182
# Mean Squared Error (MSE): 685.516
# Mean Percentage Error (MPE): 14.915
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 24.445
# Mean Squared Error (MSE): 597.571
# Mean Percentage Error (MPE): 14.104
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 24.384
# Mean Squared Error (MSE): 594.578
# Mean Percentage Error (MPE): 14.028
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 21.522
# Mean Squared Error (MSE): 463.187
# Mean Percentage Error (MPE): 12.039
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 26.563
# Mean Squared Error (MSE): 705.614
# Mean Percentage Error (MPE): 15.121

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ------------------------------------------- Exponential Kernal ----------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        

        kernel = ExpSineSquared(length_scale=1.0, periodicity=1.0)
        
        alpha = 1e-6  
        while True:
            try:
                gpr = GaussianProcessRegressor(kernel=kernel, alpha=alpha, random_state=0)
                gpr.fit(X_train, y_train)
                break  
            except Exception as e:
                alpha *= 10 

        y_pred, sigma = gpr.predict(X_test, return_std=True)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 32.723
# Mean Squared Error (MSE): 1070.792
# Mean Percentage Error (MPE): 16.697
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 33.013
# Mean Squared Error (MSE): 1089.829
# Mean Percentage Error (MPE): 17.506
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 153.807
# Mean Squared Error (MSE): 23656.441
# Mean Percentage Error (MPE): 94.05
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 147.148
# Mean Squared Error (MSE): 21652.446
# Mean Percentage Error (MPE): 86.215
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------- Rational Quadratic Kernal --------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        kernel = RationalQuadratic(length_scale=1.0, alpha=1.0)

        gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)
        gpr.fit(X_train, y_train)
        y_pred, sigma = gpr.predict(X_test, return_std=True)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.188
# Mean Squared Error (MSE): 330.792
# Mean Percentage Error (MPE): 9.479
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.97
# Mean Squared Error (MSE): 322.906
# Mean Percentage Error (MPE): 9.367
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.425
# Mean Squared Error (MSE): 339.49
# Mean Percentage Error (MPE): 9.622
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.181
# Mean Squared Error (MSE): 330.538
# Mean Percentage Error (MPE): 9.484
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.143
# Mean Squared Error (MSE): 329.181
# Mean Percentage Error (MPE): 9.468
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.839
# Mean Squared Error (MSE): 318.231
# Mean Percentage Error (MPE): 9.339
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.462
# Mean Squared Error (MSE): 340.851
# Mean Percentage Error (MPE): 9.673
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.132
# Mean Squared Error (MSE): 328.757
# Mean Percentage Error (MPE): 9.498
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.144
# Mean Squared Error (MSE): 329.187
# Mean Percentage Error (MPE): 9.467
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.846
# Mean Squared Error (MSE): 318.469
# Mean Percentage Error (MPE): 9.33
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.459
# Mean Squared Error (MSE): 340.72
# Mean Percentage Error (MPE): 9.673
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.139
# Mean Squared Error (MSE): 329.029
# Mean Percentage Error (MPE): 9.511
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.065
# Mean Squared Error (MSE): 326.333
# Mean Percentage Error (MPE): 9.451
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.631
# Mean Squared Error (MSE): 310.844
# Mean Percentage Error (MPE): 9.3
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.693
# Mean Squared Error (MSE): 349.415
# Mean Percentage Error (MPE): 9.89
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 32.723
# Mean Squared Error (MSE): 1070.776
# Mean Percentage Error (MPE): 16.697
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 17.823
# Mean Squared Error (MSE): 317.66
# Mean Percentage Error (MPE): 9.432
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 17.336
# Mean Squared Error (MSE): 300.523
# Mean Percentage Error (MPE): 9.123
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 18.338
# Mean Squared Error (MSE): 336.277
# Mean Percentage Error (MPE): 9.799
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 18.871
# Mean Squared Error (MSE): 356.098
# Mean Percentage Error (MPE): 9.848
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 17.881
# Mean Squared Error (MSE): 319.737
# Mean Percentage Error (MPE): 9.477
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 17.259
# Mean Squared Error (MSE): 297.875
# Mean Percentage Error (MPE): 9.077
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 18.737
# Mean Squared Error (MSE): 351.065
# Mean Percentage Error (MPE): 10.051
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 19.824
# Mean Squared Error (MSE): 392.994
# Mean Percentage Error (MPE): 10.511
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 17.872
# Mean Squared Error (MSE): 319.394
# Mean Percentage Error (MPE): 9.464
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 17.295
# Mean Squared Error (MSE): 299.127
# Mean Percentage Error (MPE): 9.069
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 18.615
# Mean Squared Error (MSE): 346.531
# Mean Percentage Error (MPE): 9.97
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 18.771
# Mean Squared Error (MSE): 352.342
# Mean Percentage Error (MPE): 9.657
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 17.967
# Mean Squared Error (MSE): 322.798
# Mean Percentage Error (MPE): 9.52
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 18.024
# Mean Squared Error (MSE): 324.847
# Mean Percentage Error (MPE): 9.788
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 22.846
# Mean Squared Error (MSE): 521.958
# Mean Percentage Error (MPE): 12.6

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# --------------------------------------------- Maxtern Kernal ------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        kernel = Matern(length_scale=1.0, nu=2.5)

        gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)
        gpr.fit(X_train, y_train)
        y_pred, sigma = gpr.predict(X_test, return_std=True)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 32.723
# Mean Squared Error (MSE): 1070.793
# Mean Percentage Error (MPE): 16.697
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 143.443
# Mean Squared Error (MSE): 20575.886
# Mean Percentage Error (MPE): 81.189
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 153.18
# Mean Squared Error (MSE): 23464.222
# Mean Percentage Error (MPE): 93.537
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ---------------------- Gaussian Process Regression Squared exponential kernal -------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        kernel = RBF(length_scale=1.0)

        gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)
        gpr.fit(X_train, y_train)
        y_pred, sigma = gpr.predict(X_test, return_std=True)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 32.723
# Mean Squared Error (MSE): 1070.793
# Mean Percentage Error (MPE): 16.697
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 147.144
# Mean Squared Error (MSE): 21651.343
# Mean Percentage Error (MPE): 84.303
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
