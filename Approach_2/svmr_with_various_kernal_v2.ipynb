# %%
# Exploring different combinations of features and applying linear Support Vector Machine Regression (SVR) on each subset.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import ExpSineSquared, RationalQuadratic, Matern, RBF

# %%
df = pd.read_csv('../Data/avg_fitted_ellipse_parameter_and_true_volume.csv')

# %%
columns = ['apple_label', 'semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity', 'volume']

column_dict = {
    0: 'semi_major_axis',
    1: 'semi_minor_axis',
    2: 'area',
    3: 'perimeter',
    4: 'eccentricity'
}

seeds = [0, 10, 20, 30, 40]

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ------------------------------------------- Linear Kernal ---------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        svr_model = SVR(kernel='linear')
        svr_model.fit(X_train, y_train)
        y_pred = svr_model.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25826.161
# Mean Squared Error (MSE): 666990599.563
# Mean Percentage Error (MPE): 13190.896
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 32466.701
# Mean Squared Error (MSE): 1054086645.882
# Mean Percentage Error (MPE): 20735.843
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 14238.564
# Mean Squared Error (MSE): 202736712.239
# Mean Percentage Error (MPE): 8120.05
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 34548.451
# Mean Squared Error (MSE): 1193595447.375
# Mean Percentage Error (MPE): 17385.334
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 15.22
# Mean Squared Error (MSE): 231.654
# Mean Percentage Error (MPE): 7.653
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 15.779
# Mean Squared Error (MSE): 248.974
# Mean Percentage Error (MPE): 8.207
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 15.477
# Mean Squared Error (MSE): 239.538
# Mean Percentage Error (MPE): 7.925
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.741
# Mean Squared Error (MSE): 280.246
# Mean Percentage Error (MPE): 8.892
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 21905.338
# Mean Squared Error (MSE): 479843835.633
# Mean Percentage Error (MPE): 11718.4
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 11803.823
# Mean Squared Error (MSE): 139330247.177
# Mean Percentage Error (MPE): 6036.955
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 35880.14
# Mean Squared Error (MSE): 1287384432.759
# Mean Percentage Error (MPE): 24987.789
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 8081.695
# Mean Squared Error (MSE): 65313800.779
# Mean Percentage Error (MPE): 5705.688
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 15.587
# Mean Squared Error (MSE): 242.968
# Mean Percentage Error (MPE): 7.961
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 15.029
# Mean Squared Error (MSE): 225.874
# Mean Percentage Error (MPE): 7.146
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 19.989
# Mean Squared Error (MSE): 399.57
# Mean Percentage Error (MPE): 10.725
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 32.902
# Mean Squared Error (MSE): 1082.573
# Mean Percentage Error (MPE): 18.11
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 23730.197
# Mean Squared Error (MSE): 563122246.022
# Mean Percentage Error (MPE): 16004.071
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 32434.766
# Mean Squared Error (MSE): 1052014013.273
# Mean Percentage Error (MPE): 15031.782
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 48813.98
# Mean Squared Error (MSE): 2382804641.239
# Mean Percentage Error (MPE): 31946.181
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 30087.68
# Mean Squared Error (MSE): 905268504.636
# Mean Percentage Error (MPE): 14838.637
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 15.165
# Mean Squared Error (MSE): 229.967
# Mean Percentage Error (MPE): 7.59
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 15.534
# Mean Squared Error (MSE): 241.295
# Mean Percentage Error (MPE): 7.997
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 15.846
# Mean Squared Error (MSE): 251.107
# Mean Percentage Error (MPE): 8.21
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 16.667
# Mean Squared Error (MSE): 277.798
# Mean Percentage Error (MPE): 8.878
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 12045.679
# Mean Squared Error (MSE): 145098376.308
# Mean Percentage Error (MPE): 6726.302
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 19883.575
# Mean Squared Error (MSE): 395356557.857
# Mean Percentage Error (MPE): 11662.746
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 30910.628
# Mean Squared Error (MSE): 955466939.814
# Mean Percentage Error (MPE): 21096.6
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 19717.662
# Mean Squared Error (MSE): 388786194.659
# Mean Percentage Error (MPE): 13674.811
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 15.574
# Mean Squared Error (MSE): 242.546
# Mean Percentage Error (MPE): 7.965
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 15.02
# Mean Squared Error (MSE): 225.598
# Mean Percentage Error (MPE): 7.11
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 20.168
# Mean Squared Error (MSE): 406.729
# Mean Percentage Error (MPE): 10.842

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ------------------------------------------- Guassian Kernal -------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        svr_model = SVR(kernel='rbf')
        svr_model.fit(X_train, y_train)
        y_pred = svr_model.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 27.819
# Mean Squared Error (MSE): 773.909
# Mean Percentage Error (MPE): 15.026
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 27.566
# Mean Squared Error (MSE): 759.907
# Mean Percentage Error (MPE): 14.894
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 27.566
# Mean Squared Error (MSE): 759.899
# Mean Percentage Error (MPE): 14.894
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 27.087
# Mean Squared Error (MSE): 733.71
# Mean Percentage Error (MPE): 14.638
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 30.912
# Mean Squared Error (MSE): 955.548
# Mean Percentage Error (MPE): 16.549
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 30.834
# Mean Squared Error (MSE): 950.733
# Mean Percentage Error (MPE): 16.512
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 30.836
# Mean Squared Error (MSE): 950.841
# Mean Percentage Error (MPE): 16.513
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 30.593
# Mean Squared Error (MSE): 935.946
# Mean Percentage Error (MPE): 16.399
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 27.576
# Mean Squared Error (MSE): 760.43
# Mean Percentage Error (MPE): 14.899
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 27.102
# Mean Squared Error (MSE): 734.529
# Mean Percentage Error (MPE): 14.646
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 27.102
# Mean Squared Error (MSE): 734.517
# Mean Percentage Error (MPE): 14.646
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 26.127
# Mean Squared Error (MSE): 682.626
# Mean Percentage Error (MPE): 14.142
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 29.577
# Mean Squared Error (MSE): 874.805
# Mean Percentage Error (MPE): 15.911
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 30.034
# Mean Squared Error (MSE): 902.066
# Mean Percentage Error (MPE): 16.067
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 31.117
# Mean Squared Error (MSE): 968.276
# Mean Percentage Error (MPE): 16.718
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 32.263
# Mean Squared Error (MSE): 1040.882
# Mean Percentage Error (MPE): 17.002
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 27.565
# Mean Squared Error (MSE): 759.802
# Mean Percentage Error (MPE): 14.893
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 27.084
# Mean Squared Error (MSE): 733.56
# Mean Percentage Error (MPE): 14.636
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 27.084
# Mean Squared Error (MSE): 733.549
# Mean Percentage Error (MPE): 14.636
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 26.087
# Mean Squared Error (MSE): 680.55
# Mean Percentage Error (MPE): 14.124
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 30.353
# Mean Squared Error (MSE): 921.335
# Mean Percentage Error (MPE): 16.285
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 29.706
# Mean Squared Error (MSE): 882.475
# Mean Percentage Error (MPE): 15.975
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 29.66
# Mean Squared Error (MSE): 879.698
# Mean Percentage Error (MPE): 15.952
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 24.196
# Mean Squared Error (MSE): 585.441
# Mean Percentage Error (MPE): 12.715
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 27.099
# Mean Squared Error (MSE): 734.369
# Mean Percentage Error (MPE): 14.644
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 26.121
# Mean Squared Error (MSE): 682.309
# Mean Percentage Error (MPE): 14.139
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 26.121
# Mean Squared Error (MSE): 682.285
# Mean Percentage Error (MPE): 14.139
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 24.205
# Mean Squared Error (MSE): 585.889
# Mean Percentage Error (MPE): 12.602
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 24.302
# Mean Squared Error (MSE): 590.572
# Mean Percentage Error (MPE): 12.809
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 23.544
# Mean Squared Error (MSE): 554.339
# Mean Percentage Error (MPE): 11.922
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 26.244
# Mean Squared Error (MSE): 688.732
# Mean Percentage Error (MPE): 14.151

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ------------------------------------------- Polynomial Kernal -----------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        svr_model = SVR(kernel='poly', degree=3)
        svr_model.fit(X_train, y_train)
        y_pred = svr_model.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.994
# Mean Squared Error (MSE): 323.791
# Mean Percentage Error (MPE): 10.178
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.707
# Mean Squared Error (MSE): 313.536
# Mean Percentage Error (MPE): 9.863
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.707
# Mean Squared Error (MSE): 313.521
# Mean Percentage Error (MPE): 9.862
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.474
# Mean Squared Error (MSE): 305.355
# Mean Percentage Error (MPE): 9.518
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.681
# Mean Squared Error (MSE): 348.99
# Mean Percentage Error (MPE): 10.522
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.364
# Mean Squared Error (MSE): 337.253
# Mean Percentage Error (MPE): 10.296
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.304
# Mean Squared Error (MSE): 335.028
# Mean Percentage Error (MPE): 10.259
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.538
# Mean Squared Error (MSE): 307.596
# Mean Percentage Error (MPE): 9.608
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.726
# Mean Squared Error (MSE): 314.208
# Mean Percentage Error (MPE): 9.881
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.474
# Mean Squared Error (MSE): 305.355
# Mean Percentage Error (MPE): 9.518
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.474
# Mean Squared Error (MSE): 305.355
# Mean Percentage Error (MPE): 9.518
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.539
# Mean Squared Error (MSE): 343.684
# Mean Percentage Error (MPE): 9.548
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.131
# Mean Squared Error (MSE): 293.476
# Mean Percentage Error (MPE): 8.922
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.549
# Mean Squared Error (MSE): 273.863
# Mean Percentage Error (MPE): 8.734
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 20.837
# Mean Squared Error (MSE): 434.199
# Mean Percentage Error (MPE): 11.907
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 28.454
# Mean Squared Error (MSE): 809.638
# Mean Percentage Error (MPE): 14.736
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 17.701
# Mean Squared Error (MSE): 313.328
# Mean Percentage Error (MPE): 9.856
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 17.474
# Mean Squared Error (MSE): 305.355
# Mean Percentage Error (MPE): 9.518
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 17.474
# Mean Squared Error (MSE): 305.355
# Mean Percentage Error (MPE): 9.518
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 18.539
# Mean Squared Error (MSE): 343.684
# Mean Percentage Error (MPE): 9.548
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 17.393
# Mean Squared Error (MSE): 302.526
# Mean Percentage Error (MPE): 9.446
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 17.199
# Mean Squared Error (MSE): 295.816
# Mean Percentage Error (MPE): 9.019
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 17.297
# Mean Squared Error (MSE): 299.193
# Mean Percentage Error (MPE): 9.122
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 17.933
# Mean Squared Error (MSE): 321.593
# Mean Percentage Error (MPE): 9.367
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 17.474
# Mean Squared Error (MSE): 305.355
# Mean Percentage Error (MPE): 9.518
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 18.539
# Mean Squared Error (MSE): 343.684
# Mean Percentage Error (MPE): 9.548
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 18.539
# Mean Squared Error (MSE): 343.684
# Mean Percentage Error (MPE): 9.548
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 18.837
# Mean Squared Error (MSE): 354.849
# Mean Percentage Error (MPE): 9.515
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 18.014
# Mean Squared Error (MSE): 324.486
# Mean Percentage Error (MPE): 9.006
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 18.046
# Mean Squared Error (MSE): 325.672
# Mean Percentage Error (MPE): 9.107
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 20.621
# Mean Squared Error (MSE): 425.236
# Mean Percentage Error (MPE): 11.935

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ------------------------------------------- Exponential Kernal ----------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        kernel = ExpSineSquared(length_scale=1.0, periodicity=1.0)
        
        alpha = 1e-6  
        while True:
            try:
                gpr = GaussianProcessRegressor(kernel=kernel, alpha=alpha, random_state=0)
                gpr.fit(X_train, y_train)
                break  
            except Exception as e:
                alpha *= 10 

        y_pred, sigma = gpr.predict(X_test, return_std=True)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 40.751
# Mean Squared Error (MSE): 1660.66
# Mean Percentage Error (MPE): 19.512
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 40.225
# Mean Squared Error (MSE): 1618.043
# Mean Percentage Error (MPE): 19.491
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 41.23
# Mean Squared Error (MSE): 1699.876
# Mean Percentage Error (MPE): 20.917
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 33.143
# Mean Squared Error (MSE): 1098.465
# Mean Percentage Error (MPE): 17.057
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.245
# Mean Squared Error (MSE): 1242.176
# Mean Percentage Error (MPE): 17.909
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 86.929
# Mean Squared Error (MSE): 7556.729
# Mean Percentage Error (MPE): 48.643
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 34.744
# Mean Squared Error (MSE): 1207.129
# Mean Percentage Error (MPE): 19.47
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 41.573
# Mean Squared Error (MSE): 1728.336
# Mean Percentage Error (MPE): 20.399
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 41.766
# Mean Squared Error (MSE): 1744.397
# Mean Percentage Error (MPE): 19.139
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 40.623
# Mean Squared Error (MSE): 1650.216
# Mean Percentage Error (MPE): 19.166
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 33.013
# Mean Squared Error (MSE): 1089.829
# Mean Percentage Error (MPE): 17.506
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.363
# Mean Squared Error (MSE): 1250.509
# Mean Percentage Error (MPE): 19.068
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 32.723
# Mean Squared Error (MSE): 1070.793
# Mean Percentage Error (MPE): 16.697
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 39.469
# Mean Squared Error (MSE): 1557.793
# Mean Percentage Error (MPE): 19.198
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 39.903
# Mean Squared Error (MSE): 1592.268
# Mean Percentage Error (MPE): 20.083
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 38.656
# Mean Squared Error (MSE): 1494.267
# Mean Percentage Error (MPE): 19.662
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 35.02
# Mean Squared Error (MSE): 1226.384
# Mean Percentage Error (MPE): 18.743
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 35.244
# Mean Squared Error (MSE): 1242.17
# Mean Percentage Error (MPE): 17.909
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 43.125
# Mean Squared Error (MSE): 1859.786
# Mean Percentage Error (MPE): 19.627
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 44.414
# Mean Squared Error (MSE): 1972.635
# Mean Percentage Error (MPE): 22.659
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 39.991
# Mean Squared Error (MSE): 1599.28
# Mean Percentage Error (MPE): 21.928
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 42.89
# Mean Squared Error (MSE): 1839.516
# Mean Percentage Error (MPE): 19.967
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 40.517
# Mean Squared Error (MSE): 1641.593
# Mean Percentage Error (MPE): 19.45
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 38.915
# Mean Squared Error (MSE): 1514.355
# Mean Percentage Error (MPE): 17.678
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 33.914
# Mean Squared Error (MSE): 1150.174
# Mean Percentage Error (MPE): 19.037
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 141.828
# Mean Squared Error (MSE): 20115.291
# Mean Percentage Error (MPE): 84.097
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 35.926
# Mean Squared Error (MSE): 1290.675
# Mean Percentage Error (MPE): 20.053

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------- Rational Quadratic Kernal --------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        kernel = RationalQuadratic(length_scale=1.0, alpha=1.0)

        gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)
        gpr.fit(X_train, y_train)
        y_pred, sigma = gpr.predict(X_test, return_std=True)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.721
# Mean Squared Error (MSE): 350.469
# Mean Percentage Error (MPE): 9.623
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.736
# Mean Squared Error (MSE): 351.031
# Mean Percentage Error (MPE): 9.632
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.732
# Mean Squared Error (MSE): 350.901
# Mean Percentage Error (MPE): 9.63
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.758
# Mean Squared Error (MSE): 351.849
# Mean Percentage Error (MPE): 9.646
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.001
# Mean Squared Error (MSE): 324.022
# Mean Percentage Error (MPE): 9.455
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.113
# Mean Squared Error (MSE): 328.077
# Mean Percentage Error (MPE): 9.449
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.349
# Mean Squared Error (MSE): 336.677
# Mean Percentage Error (MPE): 9.621
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 19.808
# Mean Squared Error (MSE): 392.349
# Mean Percentage Error (MPE): 10.517
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.724
# Mean Squared Error (MSE): 350.592
# Mean Percentage Error (MPE): 9.625
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.742
# Mean Squared Error (MSE): 351.245
# Mean Percentage Error (MPE): 9.637
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.737
# Mean Squared Error (MSE): 351.087
# Mean Percentage Error (MPE): 9.634
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.771
# Mean Squared Error (MSE): 352.342
# Mean Percentage Error (MPE): 9.657
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.997
# Mean Squared Error (MSE): 323.886
# Mean Percentage Error (MPE): 9.537
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.647
# Mean Squared Error (MSE): 311.408
# Mean Percentage Error (MPE): 9.558
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 22.638
# Mean Squared Error (MSE): 512.466
# Mean Percentage Error (MPE): 12.49
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 32.723
# Mean Squared Error (MSE): 1070.806
# Mean Percentage Error (MPE): 16.697
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 18.721
# Mean Squared Error (MSE): 350.469
# Mean Percentage Error (MPE): 9.623
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 18.736
# Mean Squared Error (MSE): 351.031
# Mean Percentage Error (MPE): 9.632
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 18.732
# Mean Squared Error (MSE): 350.902
# Mean Percentage Error (MPE): 9.63
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 18.758
# Mean Squared Error (MSE): 351.849
# Mean Percentage Error (MPE): 9.646
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 18.001
# Mean Squared Error (MSE): 324.024
# Mean Percentage Error (MPE): 9.455
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 18.113
# Mean Squared Error (MSE): 328.079
# Mean Percentage Error (MPE): 9.449
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 18.349
# Mean Squared Error (MSE): 336.68
# Mean Percentage Error (MPE): 9.621
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 19.824
# Mean Squared Error (MSE): 392.994
# Mean Percentage Error (MPE): 10.511
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 18.724
# Mean Squared Error (MSE): 350.592
# Mean Percentage Error (MPE): 9.625
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 18.742
# Mean Squared Error (MSE): 351.245
# Mean Percentage Error (MPE): 9.637
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 18.737
# Mean Squared Error (MSE): 351.087
# Mean Percentage Error (MPE): 9.634
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 18.771
# Mean Squared Error (MSE): 352.342
# Mean Percentage Error (MPE): 9.657
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 17.997
# Mean Squared Error (MSE): 323.886
# Mean Percentage Error (MPE): 9.537
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 18.024
# Mean Squared Error (MSE): 324.847
# Mean Percentage Error (MPE): 9.788
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 22.846
# Mean Squared Error (MSE): 521.959
# Mean Percentage Error (MPE): 12.6

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# --------------------------------------------- Maxtern Kernal ------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        kernel = Matern(length_scale=1.0, nu=2.5)

        gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)
        gpr.fit(X_train, y_train)
        y_pred, sigma = gpr.predict(X_test, return_std=True)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 83.564
# Mean Squared Error (MSE): 6982.87
# Mean Percentage Error (MPE): 36.917
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 83.416
# Mean Squared Error (MSE): 6958.168
# Mean Percentage Error (MPE): 37.734
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 86.745
# Mean Squared Error (MSE): 7524.713
# Mean Percentage Error (MPE): 39.676
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 117.892
# Mean Squared Error (MSE): 13898.509
# Mean Percentage Error (MPE): 58.053
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 72.409
# Mean Squared Error (MSE): 5243.005
# Mean Percentage Error (MPE): 32.262
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 32.723
# Mean Squared Error (MSE): 1070.793
# Mean Percentage Error (MPE): 16.697
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 83.574
# Mean Squared Error (MSE): 6984.669
# Mean Percentage Error (MPE): 36.923
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 83.429
# Mean Squared Error (MSE): 6960.382
# Mean Percentage Error (MPE): 37.743
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 86.771
# Mean Squared Error (MSE): 7529.137
# Mean Percentage Error (MPE): 39.693
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 72.429
# Mean Squared Error (MSE): 5245.946
# Mean Percentage Error (MPE): 32.273
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ---------------------- Gaussian Process Regression Squared exponential kernal -------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        kernel = RBF(length_scale=1.0)

        gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)
        gpr.fit(X_train, y_train)
        y_pred, sigma = gpr.predict(X_test, return_std=True)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 108.08
# Mean Squared Error (MSE): 11681.388
# Mean Percentage Error (MPE): 53.143
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 107.22
# Mean Squared Error (MSE): 11496.077
# Mean Percentage Error (MPE): 53.244
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 112.666
# Mean Squared Error (MSE): 12693.656
# Mean Percentage Error (MPE): 58.366
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 132.192
# Mean Squared Error (MSE): 17474.701
# Mean Percentage Error (MPE): 70.58
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 100.456
# Mean Squared Error (MSE): 10091.482
# Mean Percentage Error (MPE): 49.586
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 32.723
# Mean Squared Error (MSE): 1070.793
# Mean Percentage Error (MPE): 16.697
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 108.109
# Mean Squared Error (MSE): 11687.505
# Mean Percentage Error (MPE): 53.169
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 107.254
# Mean Squared Error (MSE): 11503.489
# Mean Percentage Error (MPE): 53.271
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 112.732
# Mean Squared Error (MSE): 12708.483
# Mean Percentage Error (MPE): 58.417
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 100.487
# Mean Squared Error (MSE): 10097.664
# Mean Percentage Error (MPE): 49.61
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
