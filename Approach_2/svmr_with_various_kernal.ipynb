# %%
'''
    Exploring different combinations of features and applying various kernal Support Vector Machine Regression (SVR) on each fitted ellipse 
    parameter subset.
'''

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import ExpSineSquared, RationalQuadratic, Matern, RBF

# %%
df = pd.read_csv('../Data/fitted_ellipse_parameter_and_true_volumn_mapper.csv')

# %%
columns = ['apple_label', 'semi_major_axis', 'semi_minor_axis', 'xc', 'yc', 'theta', 'area', 'perimeter', 'eccentricity', 'volume']

column_dict = {
    0: 'semi_major_axis',
    1: 'semi_minor_axis',
    2: 'area',
    3: 'perimeter',
    4: 'eccentricity'
}

seeds = [0]

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ------------------------------------------- Linear Kernal ---------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label', 'xc', 'yc', 'theta']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        svr_model = SVR(kernel='linear')
        svr_model.fit(X_train, y_train)
        y_pred = svr_model.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 27623.276
# Mean Squared Error (MSE): 763045354.651
# Mean Percentage Error (MPE): 15431.507
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 52047.411
# Mean Squared Error (MSE): 2708932977.359
# Mean Percentage Error (MPE): 23705.104
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 35159.52
# Mean Squared Error (MSE): 1236191860.87
# Mean Percentage Error (MPE): 16644.913
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 26999.775
# Mean Squared Error (MSE): 728987838.672
# Mean Percentage Error (MPE): 10067.874
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 19.823
# Mean Squared Error (MSE): 392.948
# Mean Percentage Error (MPE): 9.477
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 19.959
# Mean Squared Error (MSE): 398.381
# Mean Percentage Error (MPE): 9.412
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 19.962
# Mean Squared Error (MSE): 398.47
# Mean Percentage Error (MPE): 9.43
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 20.204
# Mean Squared Error (MSE): 408.22
# Mean Percentage Error (MPE): 9.71

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ------------------------------------------- Guassian Kernal -------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label', 'xc', 'yc', 'theta']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        svr_model = SVR(kernel='rbf')
        svr_model.fit(X_train, y_train)
        y_pred = svr_model.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.815
# Mean Squared Error (MSE): 475.877
# Mean Percentage Error (MPE): 10.303
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.795
# Mean Squared Error (MSE): 475.007
# Mean Percentage Error (MPE): 10.249
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.795
# Mean Squared Error (MSE): 475.006
# Mean Percentage Error (MPE): 10.249
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.742
# Mean Squared Error (MSE): 472.725
# Mean Percentage Error (MPE): 10.15
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.237
# Mean Squared Error (MSE): 636.914
# Mean Percentage Error (MPE): 12.331
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 24.966
# Mean Squared Error (MSE): 623.316
# Mean Percentage Error (MPE): 12.173
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.012
# Mean Squared Error (MSE): 625.606
# Mean Percentage Error (MPE): 12.201
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 24.456
# Mean Squared Error (MSE): 598.076
# Mean Percentage Error (MPE): 11.87
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.796
# Mean Squared Error (MSE): 475.081
# Mean Percentage Error (MPE): 10.252
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.743
# Mean Squared Error (MSE): 472.757
# Mean Percentage Error (MPE): 10.151
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.743
# Mean Squared Error (MSE): 472.747
# Mean Percentage Error (MPE): 10.151
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.78
# Mean Squared Error (MSE): 474.379
# Mean Percentage Error (MPE): 10.062
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 22.823
# Mean Squared Error (MSE): 520.893
# Mean Percentage Error (MPE): 10.776
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 23.922
# Mean Squared Error (MSE): 572.248
# Mean Percentage Error (MPE): 11.665
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 26.963
# Mean Squared Error (MSE): 727.004
# Mean Percentage Error (MPE): 13.555
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 38.82
# Mean Squared Error (MSE): 1506.987
# Mean Percentage Error (MPE): 20.444
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 21.794
# Mean Squared Error (MSE): 474.993
# Mean Percentage Error (MPE): 10.248
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 21.743
# Mean Squared Error (MSE): 472.754
# Mean Percentage Error (MPE): 10.151
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 21.743
# Mean Squared Error (MSE): 472.756
# Mean Percentage Error (MPE): 10.151
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 21.782
# Mean Squared Error (MSE): 474.476
# Mean Percentage Error (MPE): 10.063
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 23.928
# Mean Squared Error (MSE): 572.539
# Mean Percentage Error (MPE): 11.528
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 23.027
# Mean Squared Error (MSE): 530.24
# Mean Percentage Error (MPE): 10.921
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 23.036
# Mean Squared Error (MSE): 530.65
# Mean Percentage Error (MPE): 10.922
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 23.55
# Mean Squared Error (MSE): 554.61
# Mean Percentage Error (MPE): 10.536
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 21.74
# Mean Squared Error (MSE): 472.624
# Mean Percentage Error (MPE): 10.149
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 21.781
# Mean Squared Error (MSE): 474.405
# Mean Percentage Error (MPE): 10.063
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 21.781
# Mean Squared Error (MSE): 474.406
# Mean Percentage Error (MPE): 10.063
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 23.471
# Mean Squared Error (MSE): 550.906
# Mean Percentage Error (MPE): 10.385
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 22.855
# Mean Squared Error (MSE): 522.339
# Mean Percentage Error (MPE): 9.911
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 23.424
# Mean Squared Error (MSE): 548.688
# Mean Percentage Error (MPE): 10.476
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 26.035
# Mean Squared Error (MSE): 677.829
# Mean Percentage Error (MPE): 12.307

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ------------------------------------------- Polynomial Kernal -----------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label', 'xc', 'yc', 'theta']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        svr_model = SVR(kernel='poly', degree=3)
        svr_model.fit(X_train, y_train)
        y_pred = svr_model.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 20.109
# Mean Squared Error (MSE): 404.353
# Mean Percentage Error (MPE): 10.982
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 20.109
# Mean Squared Error (MSE): 404.39
# Mean Percentage Error (MPE): 10.964
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 20.109
# Mean Squared Error (MSE): 404.39
# Mean Percentage Error (MPE): 10.964
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 20.11
# Mean Squared Error (MSE): 404.425
# Mean Percentage Error (MPE): 10.947
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 19.638
# Mean Squared Error (MSE): 385.669
# Mean Percentage Error (MPE): 9.663
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 19.593
# Mean Squared Error (MSE): 383.894
# Mean Percentage Error (MPE): 9.638
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 19.695
# Mean Squared Error (MSE): 387.891
# Mean Percentage Error (MPE): 9.707
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 19.648
# Mean Squared Error (MSE): 386.026
# Mean Percentage Error (MPE): 9.681
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 20.109
# Mean Squared Error (MSE): 404.38
# Mean Percentage Error (MPE): 10.969
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 20.11
# Mean Squared Error (MSE): 404.426
# Mean Percentage Error (MPE): 10.947
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 20.11
# Mean Squared Error (MSE): 404.426
# Mean Percentage Error (MPE): 10.947
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 20.113
# Mean Squared Error (MSE): 404.521
# Mean Percentage Error (MPE): 10.93
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 19.126
# Mean Squared Error (MSE): 365.806
# Mean Percentage Error (MPE): 9.263
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 19.619
# Mean Squared Error (MSE): 384.907
# Mean Percentage Error (MPE): 9.515
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 22.875
# Mean Squared Error (MSE): 523.284
# Mean Percentage Error (MPE): 11.826
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 38.854
# Mean Squared Error (MSE): 1509.62
# Mean Percentage Error (MPE): 20.793
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 20.109
# Mean Squared Error (MSE): 404.39
# Mean Percentage Error (MPE): 10.964
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 20.11
# Mean Squared Error (MSE): 404.425
# Mean Percentage Error (MPE): 10.947
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 20.11
# Mean Squared Error (MSE): 404.425
# Mean Percentage Error (MPE): 10.947
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 20.113
# Mean Squared Error (MSE): 404.519
# Mean Percentage Error (MPE): 10.93
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 19.57
# Mean Squared Error (MSE): 382.968
# Mean Percentage Error (MPE): 9.627
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 19.523
# Mean Squared Error (MSE): 381.13
# Mean Percentage Error (MPE): 9.595
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 19.602
# Mean Squared Error (MSE): 384.226
# Mean Percentage Error (MPE): 9.654
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 19.626
# Mean Squared Error (MSE): 385.178
# Mean Percentage Error (MPE): 9.68
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 20.11
# Mean Squared Error (MSE): 404.426
# Mean Percentage Error (MPE): 10.947
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 20.113
# Mean Squared Error (MSE): 404.521
# Mean Percentage Error (MPE): 10.93
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 20.113
# Mean Squared Error (MSE): 404.521
# Mean Percentage Error (MPE): 10.93
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 20.13
# Mean Squared Error (MSE): 405.215
# Mean Percentage Error (MPE): 10.896

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ------------------------------------------- Exponential Kernal ----------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        kernel = ExpSineSquared(length_scale=1.0, periodicity=1.0)
        
        alpha = 1e-6  
        while True:
            try:
                gpr = GaussianProcessRegressor(kernel=kernel, alpha=alpha, random_state=0)
                gpr.fit(X_train, y_train)
                break  
            except Exception as e:
                alpha *= 10 

        y_pred, sigma = gpr.predict(X_test, return_std=True)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------- Rational Quadratic Kernal --------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        kernel = RationalQuadratic(length_scale=1.0, alpha=1.0)

        gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)
        gpr.fit(X_train, y_train)
        y_pred, sigma = gpr.predict(X_test, return_std=True)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# --------------------------------------------- Maxtern Kernal ------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        kernel = Matern(length_scale=1.0, nu=2.5)

        gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)
        gpr.fit(X_train, y_train)
        y_pred, sigma = gpr.predict(X_test, return_std=True)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ---------------------- Gaussian Process Regression Squared exponential kernal -------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        kernel = RBF(length_scale=1.0)

        gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)
        gpr.fit(X_train, y_train)
        y_pred, sigma = gpr.predict(X_test, return_std=True)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
