# %%
"""
    Exploring different combinations of features and applying various kernal Support Vector Machine Regression (SVR) on each average fitted ellipse 
    parameter subset.
    Here data is standardised before fitting SVMR.
    Robust Scaling is used here.
"""
# Out:
# '\n    Exploring different combinations of features and applying various kernal Support Vector Machine Regression (SVR) on each average fitted ellipse \n    parameter subset.\n    Here data is standardised before fitting SVMR.\n'

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import ExpSineSquared, RationalQuadratic, Matern, RBF

# %%
df = pd.read_csv('../Data/avg_fitted_ellipse_parameter_and_true_volume.csv')

# %%
columns = ['apple_label', 'semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity', 'volume']

column_dict = {
    0: 'semi_major_axis',
    1: 'semi_minor_axis',
    2: 'area',
    3: 'perimeter',
    4: 'eccentricity'
}

seeds = [0, 10, 20, 30, 40]

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ------------------------------------------- Linear Kernal ---------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)
        
        scaler = RobustScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        svr_model = SVR(kernel='linear')
        svr_model.fit(X_train, y_train)
        y_pred = svr_model.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.922
# Mean Squared Error (MSE): 286.342
# Mean Percentage Error (MPE): 8.72
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.795
# Mean Squared Error (MSE): 282.059
# Mean Percentage Error (MPE): 8.597
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.067
# Mean Squared Error (MSE): 291.268
# Mean Percentage Error (MPE): 8.875
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.933
# Mean Squared Error (MSE): 286.736
# Mean Percentage Error (MPE): 8.754
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.05
# Mean Squared Error (MSE): 290.713
# Mean Percentage Error (MPE): 8.849
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.813
# Mean Squared Error (MSE): 282.668
# Mean Percentage Error (MPE): 8.646
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.311
# Mean Squared Error (MSE): 299.667
# Mean Percentage Error (MPE): 9.169
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.234
# Mean Squared Error (MSE): 297.02
# Mean Percentage Error (MPE): 9.105
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.894
# Mean Squared Error (MSE): 285.391
# Mean Percentage Error (MPE): 8.701
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.662
# Mean Squared Error (MSE): 277.638
# Mean Percentage Error (MPE): 8.515
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.174
# Mean Squared Error (MSE): 294.942
# Mean Percentage Error (MPE): 9.047
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 16.789
# Mean Squared Error (MSE): 281.855
# Mean Percentage Error (MPE): 8.853
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.179
# Mean Squared Error (MSE): 295.111
# Mean Percentage Error (MPE): 9.029
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.286
# Mean Squared Error (MSE): 298.803
# Mean Percentage Error (MPE): 9.223
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.655
# Mean Squared Error (MSE): 311.697
# Mean Percentage Error (MPE): 9.542
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 31.147
# Mean Squared Error (MSE): 970.14
# Mean Percentage Error (MPE): 16.327
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 17.401
# Mean Squared Error (MSE): 302.787
# Mean Percentage Error (MPE): 9.196
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 16.993
# Mean Squared Error (MSE): 288.77
# Mean Percentage Error (MPE): 8.785
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 18.148
# Mean Squared Error (MSE): 329.354
# Mean Percentage Error (MPE): 9.962
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 17.514
# Mean Squared Error (MSE): 306.744
# Mean Percentage Error (MPE): 9.391
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 17.49
# Mean Squared Error (MSE): 305.895
# Mean Percentage Error (MPE): 9.332
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 16.958
# Mean Squared Error (MSE): 287.569
# Mean Percentage Error (MPE): 8.797
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 18.918
# Mean Squared Error (MSE): 357.881
# Mean Percentage Error (MPE): 10.577
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 18.102
# Mean Squared Error (MSE): 327.679
# Mean Percentage Error (MPE): 9.961
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 17.377
# Mean Squared Error (MSE): 301.961
# Mean Percentage Error (MPE): 9.184
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 16.647
# Mean Squared Error (MSE): 277.124
# Mean Percentage Error (MPE): 8.497
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 18.436
# Mean Squared Error (MSE): 339.896
# Mean Percentage Error (MPE): 10.287
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 17.725
# Mean Squared Error (MSE): 314.166
# Mean Percentage Error (MPE): 9.759
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 17.533
# Mean Squared Error (MSE): 307.39
# Mean Percentage Error (MPE): 9.406
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 17.014
# Mean Squared Error (MSE): 289.475
# Mean Percentage Error (MPE): 8.941
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 21.436
# Mean Squared Error (MSE): 459.517
# Mean Percentage Error (MPE): 12.298

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ------------------------------------------- Guassian Kernal -------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        scaler = RobustScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        svr_model = SVR(kernel='rbf')
        svr_model.fit(X_train, y_train)
        y_pred = svr_model.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.142
# Mean Squared Error (MSE): 632.114
# Mean Percentage Error (MPE): 13.437
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.17
# Mean Squared Error (MSE): 633.52
# Mean Percentage Error (MPE): 13.425
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.242
# Mean Squared Error (MSE): 637.152
# Mean Percentage Error (MPE): 13.543
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.307
# Mean Squared Error (MSE): 640.445
# Mean Percentage Error (MPE): 13.597
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.14
# Mean Squared Error (MSE): 632.008
# Mean Percentage Error (MPE): 13.494
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.176
# Mean Squared Error (MSE): 633.824
# Mean Percentage Error (MPE): 13.516
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.255
# Mean Squared Error (MSE): 637.811
# Mean Percentage Error (MPE): 13.646
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.429
# Mean Squared Error (MSE): 646.639
# Mean Percentage Error (MPE): 13.795
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.228
# Mean Squared Error (MSE): 636.47
# Mean Percentage Error (MPE): 13.518
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.287
# Mean Squared Error (MSE): 639.432
# Mean Percentage Error (MPE): 13.548
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.387
# Mean Squared Error (MSE): 644.519
# Mean Percentage Error (MPE): 13.689
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.491
# Mean Squared Error (MSE): 649.784
# Mean Percentage Error (MPE): 13.825
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.263
# Mean Squared Error (MSE): 638.206
# Mean Percentage Error (MPE): 13.618
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.446
# Mean Squared Error (MSE): 647.499
# Mean Percentage Error (MPE): 13.803
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 25.562
# Mean Squared Error (MSE): 653.438
# Mean Percentage Error (MPE): 13.887
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 32.263
# Mean Squared Error (MSE): 1040.882
# Mean Percentage Error (MPE): 17.002
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 24.361
# Mean Squared Error (MSE): 593.474
# Mean Percentage Error (MPE): 12.781
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 23.922
# Mean Squared Error (MSE): 572.259
# Mean Percentage Error (MPE): 12.429
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 24.627
# Mean Squared Error (MSE): 606.47
# Mean Percentage Error (MPE): 13.079
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 24.242
# Mean Squared Error (MSE): 587.698
# Mean Percentage Error (MPE): 12.677
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 24.377
# Mean Squared Error (MSE): 594.226
# Mean Percentage Error (MPE): 12.827
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 23.765
# Mean Squared Error (MSE): 564.77
# Mean Percentage Error (MPE): 12.339
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 24.88
# Mean Squared Error (MSE): 619.006
# Mean Percentage Error (MPE): 13.256
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 24.196
# Mean Squared Error (MSE): 585.441
# Mean Percentage Error (MPE): 12.715
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 24.433
# Mean Squared Error (MSE): 596.984
# Mean Percentage Error (MPE): 12.822
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 23.802
# Mean Squared Error (MSE): 566.557
# Mean Percentage Error (MPE): 12.266
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 24.864
# Mean Squared Error (MSE): 618.202
# Mean Percentage Error (MPE): 13.221
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 24.205
# Mean Squared Error (MSE): 585.889
# Mean Percentage Error (MPE): 12.602
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 24.476
# Mean Squared Error (MSE): 599.091
# Mean Percentage Error (MPE): 12.898
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 23.544
# Mean Squared Error (MSE): 554.339
# Mean Percentage Error (MPE): 11.922
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 26.244
# Mean Squared Error (MSE): 688.732
# Mean Percentage Error (MPE): 14.151

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ------------------------------------------- Polynomial Kernal -----------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        scaler = RobustScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        svr_model = SVR(kernel='poly', degree=3)
        svr_model.fit(X_train, y_train)
        y_pred = svr_model.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.814
# Mean Squared Error (MSE): 475.855
# Mean Percentage Error (MPE): 11.445
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.694
# Mean Squared Error (MSE): 470.641
# Mean Percentage Error (MPE): 11.31
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.863
# Mean Squared Error (MSE): 477.984
# Mean Percentage Error (MPE): 11.426
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.561
# Mean Squared Error (MSE): 464.86
# Mean Percentage Error (MPE): 11.057
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 22.333
# Mean Squared Error (MSE): 498.745
# Mean Percentage Error (MPE): 11.657
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 22.276
# Mean Squared Error (MSE): 496.219
# Mean Percentage Error (MPE): 11.614
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 22.734
# Mean Squared Error (MSE): 516.83
# Mean Percentage Error (MPE): 11.815
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 22.55
# Mean Squared Error (MSE): 508.499
# Mean Percentage Error (MPE): 11.588
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.751
# Mean Squared Error (MSE): 473.106
# Mean Percentage Error (MPE): 11.381
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.396
# Mean Squared Error (MSE): 457.77
# Mean Percentage Error (MPE): 11.071
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.644
# Mean Squared Error (MSE): 468.456
# Mean Percentage Error (MPE): 11.167
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.056
# Mean Squared Error (MSE): 443.375
# Mean Percentage Error (MPE): 10.995
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 22.322
# Mean Squared Error (MSE): 498.26
# Mean Percentage Error (MPE): 11.621
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 21.857
# Mean Squared Error (MSE): 477.718
# Mean Percentage Error (MPE): 11.317
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 23.09
# Mean Squared Error (MSE): 533.164
# Mean Percentage Error (MPE): 11.651
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 30.073
# Mean Squared Error (MSE): 904.41
# Mean Percentage Error (MPE): 14.806
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 24.863
# Mean Squared Error (MSE): 618.149
# Mean Percentage Error (MPE): 14.185
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 24.163
# Mean Squared Error (MSE): 583.865
# Mean Percentage Error (MPE): 13.818
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 25.86
# Mean Squared Error (MSE): 668.747
# Mean Percentage Error (MPE): 14.709
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 25.279
# Mean Squared Error (MSE): 639.032
# Mean Percentage Error (MPE): 14.394
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 24.99
# Mean Squared Error (MSE): 624.505
# Mean Percentage Error (MPE): 14.197
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 23.66
# Mean Squared Error (MSE): 559.772
# Mean Percentage Error (MPE): 13.443
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 26.003
# Mean Squared Error (MSE): 676.135
# Mean Percentage Error (MPE): 14.784
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 24.996
# Mean Squared Error (MSE): 624.822
# Mean Percentage Error (MPE): 14.206
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 24.856
# Mean Squared Error (MSE): 617.81
# Mean Percentage Error (MPE): 14.181
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 23.558
# Mean Squared Error (MSE): 554.99
# Mean Percentage Error (MPE): 13.463
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 26.349
# Mean Squared Error (MSE): 694.259
# Mean Percentage Error (MPE): 14.975
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 24.489
# Mean Squared Error (MSE): 599.703
# Mean Percentage Error (MPE): 14.125
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 24.926
# Mean Squared Error (MSE): 621.285
# Mean Percentage Error (MPE): 14.152
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 21.567
# Mean Squared Error (MSE): 465.14
# Mean Percentage Error (MPE): 11.876
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 27.068
# Mean Squared Error (MSE): 732.654
# Mean Percentage Error (MPE): 15.341

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ------------------------------------------- Exponential Kernal ----------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        scaler = RobustScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        

        kernel = ExpSineSquared(length_scale=1.0, periodicity=1.0)
        
        alpha = 1e-6  
        while True:
            try:
                gpr = GaussianProcessRegressor(kernel=kernel, alpha=alpha, random_state=0)
                gpr.fit(X_train, y_train)
                break  
            except Exception as e:
                alpha *= 10 

        y_pred, sigma = gpr.predict(X_test, return_std=True)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 70.739
# Mean Squared Error (MSE): 5004.008
# Mean Percentage Error (MPE): 37.764
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 70.739
# Mean Squared Error (MSE): 5004.008
# Mean Percentage Error (MPE): 37.764
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 70.739
# Mean Squared Error (MSE): 5004.008
# Mean Percentage Error (MPE): 37.764
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 70.739
# Mean Squared Error (MSE): 5004.008
# Mean Percentage Error (MPE): 37.764
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 70.739
# Mean Squared Error (MSE): 5004.008
# Mean Percentage Error (MPE): 37.764
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 70.739
# Mean Squared Error (MSE): 5004.008
# Mean Percentage Error (MPE): 37.764
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 70.739
# Mean Squared Error (MSE): 5004.008
# Mean Percentage Error (MPE): 37.764
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 32.723
# Mean Squared Error (MSE): 1070.792
# Mean Percentage Error (MPE): 16.697
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 33.013
# Mean Squared Error (MSE): 1089.829
# Mean Percentage Error (MPE): 17.506
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 157.799
# Mean Squared Error (MSE): 24900.624
# Mean Percentage Error (MPE): 98.846
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 153.807
# Mean Squared Error (MSE): 23656.441
# Mean Percentage Error (MPE): 94.05
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 35.239
# Mean Squared Error (MSE): 1241.784
# Mean Percentage Error (MPE): 17.905
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 147.148
# Mean Squared Error (MSE): 21652.446
# Mean Percentage Error (MPE): 86.215
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 155.79
# Mean Squared Error (MSE): 24270.623
# Mean Percentage Error (MPE): 95.998

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------- Rational Quadratic Kernal --------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        scaler = RobustScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        kernel = RationalQuadratic(length_scale=1.0, alpha=1.0)

        gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)
        gpr.fit(X_train, y_train)
        y_pred, sigma = gpr.predict(X_test, return_std=True)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.231
# Mean Squared Error (MSE): 332.375
# Mean Percentage Error (MPE): 9.497
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.994
# Mean Squared Error (MSE): 323.785
# Mean Percentage Error (MPE): 9.37
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.462
# Mean Squared Error (MSE): 340.861
# Mean Percentage Error (MPE): 9.632
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.196
# Mean Squared Error (MSE): 331.103
# Mean Percentage Error (MPE): 9.484
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.202
# Mean Squared Error (MSE): 331.306
# Mean Percentage Error (MPE): 9.493
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.867
# Mean Squared Error (MSE): 319.247
# Mean Percentage Error (MPE): 9.342
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.509
# Mean Squared Error (MSE): 342.584
# Mean Percentage Error (MPE): 9.682
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.139
# Mean Squared Error (MSE): 329.024
# Mean Percentage Error (MPE): 9.483
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.196
# Mean Squared Error (MSE): 331.107
# Mean Percentage Error (MPE): 9.491
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.861
# Mean Squared Error (MSE): 319.016
# Mean Percentage Error (MPE): 9.331
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.507
# Mean Squared Error (MSE): 342.508
# Mean Percentage Error (MPE): 9.687
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.145
# Mean Squared Error (MSE): 329.244
# Mean Percentage Error (MPE): 9.503
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.133
# Mean Squared Error (MSE): 328.803
# Mean Percentage Error (MPE): 9.478
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 17.623
# Mean Squared Error (MSE): 310.575
# Mean Percentage Error (MPE): 9.292
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 18.727
# Mean Squared Error (MSE): 350.711
# Mean Percentage Error (MPE): 9.883
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 32.723
# Mean Squared Error (MSE): 1070.784
# Mean Percentage Error (MPE): 16.697
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 17.876
# Mean Squared Error (MSE): 319.546
# Mean Percentage Error (MPE): 9.463
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 17.345
# Mean Squared Error (MSE): 300.853
# Mean Percentage Error (MPE): 9.128
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 18.364
# Mean Squared Error (MSE): 337.242
# Mean Percentage Error (MPE): 9.816
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 18.884
# Mean Squared Error (MSE): 356.618
# Mean Percentage Error (MPE): 9.86
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 17.945
# Mean Squared Error (MSE): 322.006
# Mean Percentage Error (MPE): 9.515
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 17.272
# Mean Squared Error (MSE): 298.306
# Mean Percentage Error (MPE): 9.091
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 18.747
# Mean Squared Error (MSE): 351.463
# Mean Percentage Error (MPE): 10.058
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 19.824
# Mean Squared Error (MSE): 392.994
# Mean Percentage Error (MPE): 10.511
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 17.939
# Mean Squared Error (MSE): 321.79
# Mean Percentage Error (MPE): 9.502
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 17.302
# Mean Squared Error (MSE): 299.345
# Mean Percentage Error (MPE): 9.075
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 18.67
# Mean Squared Error (MSE): 348.571
# Mean Percentage Error (MPE): 10.008
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 18.771
# Mean Squared Error (MSE): 352.342
# Mean Percentage Error (MPE): 9.657
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 18.055
# Mean Squared Error (MSE): 325.999
# Mean Percentage Error (MPE): 9.57
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 18.024
# Mean Squared Error (MSE): 324.847
# Mean Percentage Error (MPE): 9.788
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 22.846
# Mean Squared Error (MSE): 521.958
# Mean Percentage Error (MPE): 12.6

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# --------------------------------------------- Maxtern Kernal ------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        scaler = RobustScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        kernel = Matern(length_scale=1.0, nu=2.5)

        gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)
        gpr.fit(X_train, y_train)
        y_pred, sigma = gpr.predict(X_test, return_std=True)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 32.723
# Mean Squared Error (MSE): 1070.793
# Mean Percentage Error (MPE): 16.697
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 143.443
# Mean Squared Error (MSE): 20575.886
# Mean Percentage Error (MPE): 81.189
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 153.18
# Mean Squared Error (MSE): 23464.073
# Mean Percentage Error (MPE): 93.543
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0

# %%
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# ---------------------- Gaussian Process Regression Squared exponential kernal -------------------------------
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
for i in range (0, 31):
    
    i_temp = i
    drop_columns = ['volume', 'apple_label']
    for j in range(5):
        if i_temp % 2 == 1:
            drop_columns.append(column_dict[j])
        i_temp //= 2

    print('\n')
    X = df.drop(columns = drop_columns).values.tolist() 
    y = df['volume'].values.tolist()  

    rmses = np.empty(0)
    mses = np.empty(0)
    mpes = np.empty(0)
    
    for i in range(len(seeds)):
    
        seed = seeds[i]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        scaler = RobustScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        kernel = RBF(length_scale=1.0)

        gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)
        gpr.fit(X_train, y_train)
        y_pred, sigma = gpr.predict(X_test, return_std=True)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mse = mean_squared_error(y_test, y_pred)
        mpe = mean_absolute_percentage_error(y_test, y_pred)

        np.append(rmses, rmse)
        np.append(mses, mse)
        np.append(mpes, mpe)

    drop_column_set = set(drop_columns)
    left_columns = [s for s in columns if s not in drop_column_set]

    print('**********************************************************')
    print("With features :", left_columns)
    print("Root Mean Squared Error (RMSE):", round(np.mean(rmse), 3))
    print("Mean Squared Error (MSE):", round(np.mean(mse), 3))
    print("Mean Percentage Error (MPE):", round(np.mean(mpe), 3))
    print("")
# Out:
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['perimeter', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'eccentricity']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['eccentricity']
# Root Mean Squared Error (RMSE): 32.723
# Mean Squared Error (MSE): 1070.793
# Mean Percentage Error (MPE): 16.697
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'perimeter']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['perimeter']
# Root Mean Squared Error (RMSE): 147.144
# Mean Squared Error (MSE): 21651.343
# Mean Percentage Error (MPE): 84.303
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis', 'area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['area']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis', 'semi_minor_axis']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_minor_axis']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
#
#
#
# **********************************************************
# With features : ['semi_major_axis']
# Root Mean Squared Error (RMSE): 158.747
# Mean Squared Error (MSE): 25200.625
# Mean Percentage Error (MPE): 100.0
